# %%
# This Colab requires a recent numpy version.
! pip install numpy==1.24.3
! pip install protobuf==3.20.3
! pip install tensorflow-hub

# %%
import os
import pathlib

import matplotlib
import matplotlib.pyplot as plt

import io
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from six.moves.urllib.request import urlopen

import tensorflow as tf
import tensorflow_hub as hub

tf.get_logger().setLevel('ERROR')

# %%
# Clone the tensorflow models repository
! git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 4065, done.
# remote: Counting objects: 100% (4065/4065), done.
# remote: Compressing objects: 100% (3104/3104), done.
# remote: Total 4065 (delta 1185), reused 1920 (delta 901), pack-reused 0
# Receiving objects: 100% (4065/4065), 54.72 MiB | 27.52 MiB/s, done.
# Resolving deltas: 100% (1185/1185), done.

# %%
! sudo apt install -y protobuf-compiler
! cd models/research/
! protoc models/research/object_detection/protos/*.proto --python_out=models/research/.
! cp models/research/object_detection/packages/tf2/setup.py models/research/.
! python -m pip install models/research/.
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# protobuf-compiler is already the newest version (3.12.4-1ubuntu7.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 84 not upgraded.
# object_detection/protos/flexible_grid_anchor_generator.proto: File not found.
# object_detection/protos/grid_anchor_generator.proto: File not found.
# object_detection/protos/multiscale_anchor_generator.proto: File not found.
# object_detection/protos/ssd_anchor_generator.proto: File not found.
# models/research/object_detection/protos/anchor_generator.proto:5:1: Import "object_detection/protos/flexible_grid_anchor_generator.proto" was not found or had errors.
# models/research/object_detection/protos/anchor_generator.proto:6:1: Import "object_detection/protos/grid_anchor_generator.proto" was not found or had errors.
# models/research/object_detection/protos/anchor_generator.proto:7:1: Import "object_detection/protos/multiscale_anchor_generator.proto" was not found or had errors.
# models/research/object_detection/protos/anchor_generator.proto:8:1: Import "object_detection/protos/ssd_anchor_generator.proto" was not found or had errors.
# models/research/object_detection/protos/anchor_generator.proto:14:5: "GridAnchorGenerator" is not defined.
# models/research/object_detection/protos/anchor_generator.proto:15:5: "SsdAnchorGenerator" is not defined.
# models/research/object_detection/protos/anchor_generator.proto:16:5: "MultiscaleAnchorGenerator" is not defined.
# models/research/object_detection/protos/anchor_generator.proto:17:5: "FlexibleGridAnchorGenerator" is not defined.
# Processing ./models/research
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: avro-python3 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (2.52.0)
# Requirement already satisfied: pillow in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (9.5.0)
# Requirement already satisfied: lxml in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (4.9.4)
# Requirement already satisfied: matplotlib in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: Cython in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (3.0.7)
# Requirement already satisfied: contextlib2 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (2.0.7)
# Requirement already satisfied: lvis in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (1.11.4)
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (2.1.4)
# Requirement already satisfied: tf-models-official>=2.5.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (2.15.0)
# Requirement already satisfied: tensorflow_io in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (0.35.0)
# Requirement already satisfied: keras in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (2.15.0)
# Requirement already satisfied: pyparsing==2.4.7 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: portalocker in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.8.2)
# Requirement already satisfied: regex in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.24.3)
# Requirement already satisfied: colorama in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: gin-config in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.111.0)
# Requirement already satisfied: immutabledict in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.0)
# Requirement already satisfied: kaggle>=1.3.9 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.16)
# Requirement already satisfied: oauth2client in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.8.1.78)
# Requirement already satisfied: psutil>=5.4.3 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.7)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (6.0.1)
# Requirement already satisfied: sentencepiece in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.1.99)
# Requirement already satisfied: seqeval in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: tensorflow-datasets in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.9.4)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.15.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.7.5)
# Requirement already satisfied: tensorflow-text~=2.15.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.15.0)
# Requirement already satisfied: tensorflow~=2.15.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pandas->object-detection==0.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pandas->object-detection==0.1) (2023.3)
# Requirement already satisfied: absl-py>=0.2.2 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (3.9.10)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (1.9.2)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (1.60.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: js2py<1,>=0.74 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (0.74)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (4.20.0)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (0.6.1)
# Requirement already satisfied: packaging>=22.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (23.2)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (4.6.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (1.23.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<4.26.0,>=3.20.3 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (4.9.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (11.0.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from apache-beam->object-detection==0.1) (0.6)
# Requirement already satisfied: cycler>=0.10.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from lvis->object-detection==0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from lvis->object-detection==0.1) (1.4.5)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from lvis->object-detection==0.1) (4.8.1.78)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from matplotlib->object-detection==0.1) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from matplotlib->object-detection==0.1) (4.47.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.35.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow_io->object-detection==0.1) (0.35.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.25.2)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.15.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: docopt in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: tzlocal>=1.2 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from js2py<1,>=0.74->apache-beam->object-detection==0.1) (5.2)
# Requirement already satisfied: pyjsparser>=2.5.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from js2py<1,>=0.74->apache-beam->object-detection==0.1) (2.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (0.15.2)
# Requirement already satisfied: certifi in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2023.11.17)
# Requirement already satisfied: tqdm in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.66.1)
# Requirement already satisfied: python-slugify in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.1)
# Requirement already satisfied: urllib3 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.1.0)
# Requirement already satisfied: bleach in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1) (2.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.6)
# Requirement already satisfied: astunparse>=1.6.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (65.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (2.15.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.5.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.3.2)
# Requirement already satisfied: click in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.7)
# Requirement already satisfied: etils[enp,epath,etree]>=0.9.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.6.0)
# Requirement already satisfied: promise in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.14.0)
# Requirement already satisfied: toml in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: array-record>=0.5.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (0.42.0)
# Requirement already satisfied: fsspec in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2023.12.2)
# Requirement already satisfied: importlib_resources in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (6.1.1)
# Requirement already satisfied: zipp in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.62.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.2)
# Requirement already satisfied: joblib>=1.1.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.2.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: webencodings in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from bleach->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/gitpod/.pyenv/versions/3.11.4/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1611156 sha256=68ace9ed89eb35c86857bcfd4bde870aeda65b76d189fcacdf13dca8afacb9ed
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rb2335cy/wheels/6e/2e/5d/08d833237559019f002719146824102e7bf011ec7e8e072191
# Successfully built object-detection
# Installing collected packages: object-detection
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# Successfully installed object-detection-0.1
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import ops as utils_ops

# %matplotlib inline

# %%
PATH_TO_LABELS = './models/research/object_detection/data/mscoco_label_map.pbtxt'
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)

model_display_name = 'CenterNet HourGlass104 Keypoints 512x512' # @param ['CenterNet HourGlass104 512x512','CenterNet HourGlass104 Keypoints 512x512','CenterNet HourGlass104 1024x1024','CenterNet HourGlass104 Keypoints 1024x1024','CenterNet Resnet50 V1 FPN 512x512','CenterNet Resnet50 V1 FPN Keypoints 512x512','CenterNet Resnet101 V1 FPN 512x512','CenterNet Resnet50 V2 512x512','CenterNet Resnet50 V2 Keypoints 512x512','EfficientDet D0 512x512','EfficientDet D1 640x640','EfficientDet D2 768x768','EfficientDet D3 896x896','EfficientDet D4 1024x1024','EfficientDet D5 1280x1280','EfficientDet D6 1280x1280','EfficientDet D7 1536x1536','SSD MobileNet v2 320x320','SSD MobileNet V1 FPN 640x640','SSD MobileNet V2 FPNLite 320x320','SSD MobileNet V2 FPNLite 640x640','SSD ResNet50 V1 FPN 640x640 (RetinaNet50)','SSD ResNet50 V1 FPN 1024x1024 (RetinaNet50)','SSD ResNet101 V1 FPN 640x640 (RetinaNet101)','SSD ResNet101 V1 FPN 1024x1024 (RetinaNet101)','SSD ResNet152 V1 FPN 640x640 (RetinaNet152)','SSD ResNet152 V1 FPN 1024x1024 (RetinaNet152)','Faster R-CNN ResNet50 V1 640x640','Faster R-CNN ResNet50 V1 1024x1024','Faster R-CNN ResNet50 V1 800x1333','Faster R-CNN ResNet101 V1 640x640','Faster R-CNN ResNet101 V1 1024x1024','Faster R-CNN ResNet101 V1 800x1333','Faster R-CNN ResNet152 V1 640x640','Faster R-CNN ResNet152 V1 1024x1024','Faster R-CNN ResNet152 V1 800x1333','Faster R-CNN Inception ResNet V2 640x640','Faster R-CNN Inception ResNet V2 1024x1024','Mask R-CNN Inception ResNet V2 1024x1024']
model_handle = ALL_MODELS[model_display_name]

print('Selected model:'+ model_display_name)
print('Model Handle at TensorFlow Hub: {}'.format(model_handle))

hub_model = hub.load(model_handle)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/google/protobuf/internal/python_message.py:855, in _AddHasFieldMethod.<locals>.HasField(self, field_name)
#     854 try:
# --> 855   field = hassable_fields[field_name]
#     856 except KeyError:
#
# KeyError: 'frequency'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /workspace/tarot/tf_object_detection.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell://zzoia-tarot-a82htn70d73.ws-eu107.gitpod.io/workspace/tarot/tf_object_detection.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> PATH_TO_LABELS = './models/research/object_detection/data/mscoco_label_map.pbtxt'
# ----> <a href='vscode-notebook-cell://zzoia-tarot-a82htn70d73.ws-eu107.gitpod.io/workspace/tarot/tf_object_detection.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)
#       <a href='vscode-notebook-cell://zzoia-tarot-a82htn70d73.ws-eu107.gitpod.io/workspace/tarot/tf_object_detection.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> model_display_name = 'CenterNet HourGlass104 Keypoints 512x512' # @param ['CenterNet HourGlass104 512x512','CenterNet HourGlass104 Keypoints 512x512','CenterNet HourGlass104 1024x1024','CenterNet HourGlass104 Keypoints 1024x1024','CenterNet Resnet50 V1 FPN 512x512','CenterNet Resnet50 V1 FPN Keypoints 512x512','CenterNet Resnet101 V1 FPN 512x512','CenterNet Resnet50 V2 512x512','CenterNet Resnet50 V2 Keypoints 512x512','EfficientDet D0 512x512','EfficientDet D1 640x640','EfficientDet D2 768x768','EfficientDet D3 896x896','EfficientDet D4 1024x1024','EfficientDet D5 1280x1280','EfficientDet D6 1280x1280','EfficientDet D7 1536x1536','SSD MobileNet v2 320x320','SSD MobileNet V1 FPN 640x640','SSD MobileNet V2 FPNLite 320x320','SSD MobileNet V2 FPNLite 640x640','SSD ResNet50 V1 FPN 640x640 (RetinaNet50)','SSD ResNet50 V1 FPN 1024x1024 (RetinaNet50)','SSD ResNet101 V1 FPN 640x640 (RetinaNet101)','SSD ResNet101 V1 FPN 1024x1024 (RetinaNet101)','SSD ResNet152 V1 FPN 640x640 (RetinaNet152)','SSD ResNet152 V1 FPN 1024x1024 (RetinaNet152)','Faster R-CNN ResNet50 V1 640x640','Faster R-CNN ResNet50 V1 1024x1024','Faster R-CNN ResNet50 V1 800x1333','Faster R-CNN ResNet101 V1 640x640','Faster R-CNN ResNet101 V1 1024x1024','Faster R-CNN ResNet101 V1 800x1333','Faster R-CNN ResNet152 V1 640x640','Faster R-CNN ResNet152 V1 1024x1024','Faster R-CNN ResNet152 V1 800x1333','Faster R-CNN Inception ResNet V2 640x640','Faster R-CNN Inception ResNet V2 1024x1024','Mask R-CNN Inception ResNet V2 1024x1024']
#       <a href='vscode-notebook-cell://zzoia-tarot-a82htn70d73.ws-eu107.gitpod.io/workspace/tarot/tf_object_detection.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> model_handle = ALL_MODELS[model_display_name]
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/object_detection/utils/label_map_util.py:378, in create_category_index_from_labelmap(label_map_path, use_display_name)
#     364 def create_category_index_from_labelmap(label_map_path, use_display_name=True):
#     365   """Reads a label map and returns a category index.
#     366
#     367   Args:
#    (...)
#     376     {1: {'id': 1, 'name': 'dog'}, 2: {'id': 2, 'name': 'cat'}, ...}
#     377   """
# --> 378   categories = create_categories_from_labelmap(label_map_path, use_display_name)
#     379   return create_category_index(categories)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/object_detection/utils/label_map_util.py:360, in create_categories_from_labelmap(label_map_path, use_display_name)
#     358 label_map = load_labelmap(label_map_path)
#     359 max_num_classes = max(item.id for item in label_map.item)
# --> 360 return convert_label_map_to_categories(label_map, max_num_classes,
#     361                                        use_display_name)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/object_detection/utils/label_map_util.py:133, in convert_label_map_to_categories(label_map, max_num_classes, use_display_name)
#     131 list_of_ids_already_added.append(item.id)
#     132 category = {'id': item.id, 'name': name}
# --> 133 if item.HasField('frequency'):
#     134   if item.frequency == string_int_label_map_pb2.LVISFrequency.Value(
#     135       'FREQUENT'):
#     136     category['frequency'] = 'f'
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/google/protobuf/internal/python_message.py:857, in _AddHasFieldMethod.<locals>.HasField(self, field_name)
#     855   field = hassable_fields[field_name]
#     856 except KeyError:
# --> 857   raise ValueError(error_msg % (message_descriptor.full_name, field_name))
#     859 if isinstance(field, descriptor_mod.OneofDescriptor):
#     860   try:
#
# ValueError: Protocol message object_detection.protos.StringIntLabelMapItem has no non-repeated field "frequency"
